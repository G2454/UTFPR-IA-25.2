# %% [markdown]
# <a href="https://colab.research.google.com/github/G2454/UTFPR-IA-25.2/blob/main/Aula_Busca_Greedy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import queue as Q

# %%
cidades = Q.PriorityQueue()

# %%
cidades.put((366, 'Arad'))
cidades.put((383, 'Sibiu'))
cidades.put((449, 'Zerind'))
cidades.put((526, 'Timisoara'))
cidades.put((417, 'Pitesti'))
cidades.put((0, 'Bucharest'))

# %%
cidades.qsize()
# Out:
# 6

# %%
print(cidades.get())
print(cidades.qsize())
# Out:
# (526, 'Timisoara')
# 0

# %%
while cidades.qsize():
  custo, cidade = cidades.get()
  print(f'Custo: {custo} - Cidade: {cidade}')
# Out:
# Custo: 0 - Cidade: Bucharest
# Custo: 366 - Cidade: Arad
# Custo: 383 - Cidade: Sibiu
# Custo: 417 - Cidade: Pitesti
# Custo: 449 - Cidade: Zerind
# Custo: 526 - Cidade: Timisoara

# %%
# Construção manual do dicionário
def criaListaAdj():
  listaAdj = {
              'Arad': {'Timisoara': 118 , 'Sibiu': 140, 'Zerind': 75 },
              'Zerind': {'Arad': 75, 'Oradea': 71},
              'Oradea': {'Zerind': 71, 'Sibiu': 151},
              'Sibiu': {'Arad': 140, 'Oradea': 151, 'Fagaras': 99, 'Rimnicu': 80},\
              'Timisoara': {'Arad': 118, 'Lugoj': 111},
              'Lugoj': {'Timisoara': 111, 'Mehadia': 70},
              'Mehadia': {'Lugoj': 70, 'Dobreta': 75},
              'Dobreta': {'Mehadia': 75, 'Craiova': 120},
              'Craiova': {'Dobreta': 120, 'Rimnicu': 146, 'Pitesti': 138},
              'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
              'Fagaras': {'Sibiu': 99, 'Bucharest': 211},
              'Pitesti': {'Rimnicu': 97, 'Craiova': 138, 'Bucharest': 101},
              'Bucharest': {'Fagaras': 211, 'Pitesti': 101, 'Giurgiu': 90, 'Urziceni': 85},
              'Giurgiu': {'Bucharest': 90},
              'Urziceni': {'Bucharest': 85, 'Vaslui': 142, 'Hirsova': 98},
              'Hirsova': {'Urziceni': 98, 'Eforie': 86},
              'Eforie': {'Hirsova': 86},
              'Vaslui': {'Iasi': 92, 'Urziceni': 142},
              'Iasi': {'Vaslui': 92, 'Neamt': 87},
              'Neamt': {'Iasi': 87}
          }
  return listaAdj

# %%
def getHeuristics():

  heuristics = {'Arad':366,
              'Bucharest':0,
              'Craiova':160,
              'Dobreta': 242,
              'Eforie': 161,
              'Fagaras': 178,
              'Giurgiu': 77,
              'Hirsova': 151,
              'Iasi': 226,
              'Lugoj': 244,
              'Mehadia': 241,
              'Neamt': 234,
              'Oradea': 380,
              'Pitesti': 98,
              'Rimnicu': 193,
              'Sibiu': 253,
              'Timisoara': 329,
              'Urziceni': 80,
              'Vaslui': 199,
              'Zerind': 374
              }
  return heuristics

# %%
from queue import PriorityQueue

# %%
# Função Greedy
def greedy(listaAdj, origem, objetivo, distancias):

    # Declara a fila prioridade e tabela de visitados
    visitados = []
    fronteira = PriorityQueue()

    # Adiciona a cidade origem em visitados
    visitados.append(origem)

    # Adiciona a cidade origem na fila
    # fila: tupla (valor (heuristica), cidade)
    fronteira.put((distancias[origem], origem))



    while not fronteira.empty() and origem != objetivo:

          # Inclui os vizinhos na fila de prioridade
      for vizinho in listaAdj[origem]:
            fronteira.put((distancias[vizinho], vizinho))

          #Remove a cidade de menor custo da fila
      custo, cidade = fronteira.get()

          # Verifica se a cidade ainda não foi visitada
      if cidade not in visitados:
            origem = cidade
            visitados.append(origem)

    return visitados

# %%
cidades = criaListaAdj()
h = getHeuristics()
solucao = greedy(cidades, 'Arad', 'Bucharest', h)
print(solucao)
# Out:
# ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']
