# %% [markdown]
# <a href="https://colab.research.google.com/github/G2454/UTFPR-IA-25.2/blob/main/Aula_KNN_Iris_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exemplo de implementação KNN**
# * https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# * Base de Dados: Iris.csv
# * https://www.kaggle.com/datasets/uciml/iris?select=Iris.csv

# %%
#Importa a biblioteca pandas
import pandas as pd

# %%
#Carrega a base Iris
data = pd.read_csv('Iris.csv')

# %%
data.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# ### Pré-processamento
# * Conversão dos dados atributo classe (species) para binário
# * LabelEncoder:
# * https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
# * Remoção do atributo Id

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Remoção da coluna Id
data.drop(['Id'], axis=1, inplace = True)

# %%
data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Transformação da classe para discreto
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# ### Divisão da base de dados entre treino e teste
# * y - Obtem os valores da classe.
# * X - Obtem os dados de treinamento (previsores).

# %%
# Biblioteca para separação treino e teste
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['Species'], axis = 1)
y = data['Species']

# %%
# Separa em treino e teste (Holdout)
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.7)

# %%
# Importa a classe KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(metric = 'euclidean')

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = knn.predict(X_test)

# %%
y_pred
# Out:
# array([0, 2, 2, 0, 0, 1, 2, 0, 2, 2, 2, 0, 1, 1, 0, 1, 2, 2, 1, 1, 0, 0,
#        0, 2, 1, 0, 2, 0, 0, 2, 1, 2, 0, 2, 2, 0, 0, 2, 0, 1, 1, 1, 2, 0,
#        0])

# %%
y_test
# Out:
# 37     0
# 112    2
# 101    2
# 7      0
# 20     0
# 56     1
# 83     1
# 21     0
# 104    2
# 146    2
# 128    2
# 36     0
# 64     1
# 91     1
# 18     0
# 60     1
# 122    2
# 129    2
# 71     1
# 95     1
# 47     0
# 41     0
# 34     0
# 148    2
# 77     1
# 44     0
# 134    2
# 19     0
# 43     0
# 123    2
# 67     1
# 143    2
# 8      0
# 145    2
# 103    2
# 12     0
# 33     0
# 147    2
# 11     0
# 82     1
# 87     1
# 69     1
# 118    2
# 48     0
# 39     0
# Name: Species, dtype: int64

# %% [markdown]
# ##### Avaliando o modelo

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9777777777777777

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# #### Avaliando com dados Normalizados

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =  StandardScaler()

# %%
data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']] =\
scaler.fit_transform(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']])

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      -0.900681      1.032057      -1.341272     -1.312977        0
# 1      -1.143017     -0.124958      -1.341272     -1.312977        0
# 2      -1.385353      0.337848      -1.398138     -1.312977        0
# 3      -1.506521      0.106445      -1.284407     -1.312977        0
# 4      -1.021849      1.263460      -1.341272     -1.312977        0

# %%
X = data.drop(['Species'], axis = 1)
y = data['Species']

# %%
# Separa em treino e teste (Holdout)
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.7)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9333333333333333
